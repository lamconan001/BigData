# %% [markdown]
# # Get winrate of each champion

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col

# %%
spark = SparkSession.builder.appName("ReadData").getOrCreate()

# %%
file_path = "D:/BigData/Data/match_detail.json"
df = spark.read.json(file_path)

# %%
df.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- info: struct (nullable = true)
#  |    |-- gameCreation: long (nullable = true)
#  |    |-- gameDuration: long (nullable = true)
#  |    |-- gameEndTimestamp: long (nullable = true)
#  |    |-- gameId: long (nullable = true)
#  |    |-- gameMode: string (nullable = true)
#  |    |-- gameName: string (nullable = true)
#  |    |-- gameStartTimestamp: long (nullable = true)
#  |    |-- gameType: string (nullable = true)
#  |    |-- gameVersion: string (nullable = true)
#  |    |-- mapId: long (nullable = true)
#  |    |-- participants: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- allInPings: long (nullable = true)
#  |    |    |    |-- assistMePings: long (nullable = true)
#  |    |    |    |-- assists: long (nullable = true)
#  |    |    |    |-- baitPings: long (nullable = true)
#  |    |    |    |-- baronKills: long (nullable = true)
#  |    |    |    |-- basicPings: long (nullable = true)
#  |    |    |    |-- bountyLevel: long (nullable = true)
#  |    |    |    |-- challenges: struct (nullable = true)
#  |    |    |    |    |-- 12AssistStreakCount: long (nullable = true)
#  |    |    |    |    |-- abilityUses: long (nullable = true)
#  |    |    |    |    |-- acesBefore15Minutes: long (nullable = true)
#  |    |    |    |    |-- alliedJungleMonsterKills: long (nullable = true)
#  |    |    |    |    |-- baronBuffGoldAdvantageOverThreshold: long (nullable = true)
#  |    |    |    |    |-- baronTakedowns: long (nullable = true)
#  |    |    |    |    |-- blastConeOppositeOpponentCount: long (nullable = true)
#  |    |    |    |    |-- bountyGold: long (nullable = true)
#  |    |    |    |    |-- buffsStolen: long (nullable = true)
#  |    |    |    |    |-- completeSupportQuestInTime: long (nullable = true)
#  |    |    |    |    |-- controlWardTimeCoverageInRiverOrEnemyHalf: double (nullable = true)
#  |    |    |    |    |-- controlWardsPlaced: long (nullable = true)
#  |    |    |    |    |-- damagePerMinute: double (nullable = true)
#  |    |    |    |    |-- damageTakenOnTeamPercentage: double (nullable = true)
#  |    |    |    |    |-- dancedWithRiftHerald: long (nullable = true)
#  |    |    |    |    |-- deathsByEnemyChamps: long (nullable = true)
#  |    |    |    |    |-- dodgeSkillShotsSmallWindow: long (nullable = true)
#  |    |    |    |    |-- doubleAces: long (nullable = true)
#  |    |    |    |    |-- dragonTakedowns: long (nullable = true)
#  |    |    |    |    |-- earliestBaron: double (nullable = true)
#  |    |    |    |    |-- earliestDragonTakedown: double (nullable = true)
#  |    |    |    |    |-- earliestElderDragon: double (nullable = true)
#  |    |    |    |    |-- earlyLaningPhaseGoldExpAdvantage: long (nullable = true)
#  |    |    |    |    |-- effectiveHealAndShielding: double (nullable = true)
#  |    |    |    |    |-- elderDragonKillsWithOpposingSoul: long (nullable = true)
#  |    |    |    |    |-- elderDragonMultikills: long (nullable = true)
#  |    |    |    |    |-- enemyChampionImmobilizations: long (nullable = true)
#  |    |    |    |    |-- enemyJungleMonsterKills: long (nullable = true)
#  |    |    |    |    |-- epicMonsterKillsNearEnemyJungler: long (nullable = true)
#  |    |    |    |    |-- epicMonsterKillsWithin30SecondsOfSpawn: long (nullable = true)
#  |    |    |    |    |-- epicMonsterSteals: long (nullable = true)
#  |    |    |    |    |-- epicMonsterStolenWithoutSmite: long (nullable = true)
#  |    |    |    |    |-- fasterSupportQuestCompletion: long (nullable = true)
#  |    |    |    |    |-- fastestLegendary: double (nullable = true)
#  |    |    |    |    |-- firstTurretKilled: long (nullable = true)
#  |    |    |    |    |-- firstTurretKilledTime: double (nullable = true)
#  |    |    |    |    |-- flawlessAces: long (nullable = true)
#  |    |    |    |    |-- fullTeamTakedown: long (nullable = true)
#  |    |    |    |    |-- gameLength: double (nullable = true)
#  |    |    |    |    |-- getTakedownsInAllLanesEarlyJungleAsLaner: long (nullable = true)
#  |    |    |    |    |-- goldPerMinute: double (nullable = true)
#  |    |    |    |    |-- hadAfkTeammate: long (nullable = true)
#  |    |    |    |    |-- hadOpenNexus: long (nullable = true)
#  |    |    |    |    |-- highestChampionDamage: long (nullable = true)
#  |    |    |    |    |-- highestCrowdControlScore: long (nullable = true)
#  |    |    |    |    |-- highestWardKills: long (nullable = true)
#  |    |    |    |    |-- immobilizeAndKillWithAlly: long (nullable = true)
#  |    |    |    |    |-- initialBuffCount: long (nullable = true)
#  |    |    |    |    |-- initialCrabCount: long (nullable = true)
#  |    |    |    |    |-- jungleCsBefore10Minutes: double (nullable = true)
#  |    |    |    |    |-- junglerKillsEarlyJungle: long (nullable = true)
#  |    |    |    |    |-- junglerTakedownsNearDamagedEpicMonster: long (nullable = true)
#  |    |    |    |    |-- kTurretsDestroyedBeforePlatesFall: long (nullable = true)
#  |    |    |    |    |-- kda: double (nullable = true)
#  |    |    |    |    |-- killAfterHiddenWithAlly: long (nullable = true)
#  |    |    |    |    |-- killParticipation: double (nullable = true)
#  |    |    |    |    |-- killedChampTookFullTeamDamageSurvived: long (nullable = true)
#  |    |    |    |    |-- killingSprees: long (nullable = true)
#  |    |    |    |    |-- killsNearEnemyTurret: long (nullable = true)
#  |    |    |    |    |-- killsOnLanersEarlyJungleAsJungler: long (nullable = true)
#  |    |    |    |    |-- killsOnOtherLanesEarlyJungleAsLaner: long (nullable = true)
#  |    |    |    |    |-- killsOnRecentlyHealedByAramPack: long (nullable = true)
#  |    |    |    |    |-- killsUnderOwnTurret: long (nullable = true)
#  |    |    |    |    |-- killsWithHelpFromEpicMonster: long (nullable = true)
#  |    |    |    |    |-- knockEnemyIntoTeamAndKill: long (nullable = true)
#  |    |    |    |    |-- landSkillShotsEarlyGame: long (nullable = true)
#  |    |    |    |    |-- laneMinionsFirst10Minutes: long (nullable = true)
#  |    |    |    |    |-- laningPhaseGoldExpAdvantage: long (nullable = true)
#  |    |    |    |    |-- legendaryCount: long (nullable = true)
#  |    |    |    |    |-- lostAnInhibitor: long (nullable = true)
#  |    |    |    |    |-- maxCsAdvantageOnLaneOpponent: double (nullable = true)
#  |    |    |    |    |-- maxKillDeficit: long (nullable = true)
#  |    |    |    |    |-- maxLevelLeadLaneOpponent: long (nullable = true)
#  |    |    |    |    |-- mejaisFullStackInTime: long (nullable = true)
#  |    |    |    |    |-- moreEnemyJungleThanOpponent: double (nullable = true)
#  |    |    |    |    |-- multiKillOneSpell: long (nullable = true)
#  |    |    |    |    |-- multiTurretRiftHeraldCount: long (nullable = true)
#  |    |    |    |    |-- multikills: long (nullable = true)
#  |    |    |    |    |-- multikillsAfterAggressiveFlash: long (nullable = true)
#  |    |    |    |    |-- mythicItemUsed: long (nullable = true)
#  |    |    |    |    |-- outerTurretExecutesBefore10Minutes: long (nullable = true)
#  |    |    |    |    |-- outnumberedKills: long (nullable = true)
#  |    |    |    |    |-- outnumberedNexusKill: long (nullable = true)
#  |    |    |    |    |-- perfectDragonSoulsTaken: long (nullable = true)
#  |    |    |    |    |-- perfectGame: long (nullable = true)
#  |    |    |    |    |-- pickKillWithAlly: long (nullable = true)
#  |    |    |    |    |-- playedChampSelectPosition: long (nullable = true)
#  |    |    |    |    |-- poroExplosions: long (nullable = true)
#  |    |    |    |    |-- quickCleanse: long (nullable = true)
#  |    |    |    |    |-- quickFirstTurret: long (nullable = true)
#  |    |    |    |    |-- quickSoloKills: long (nullable = true)
#  |    |    |    |    |-- riftHeraldTakedowns: long (nullable = true)
#  |    |    |    |    |-- saveAllyFromDeath: long (nullable = true)
#  |    |    |    |    |-- scuttleCrabKills: long (nullable = true)
#  |    |    |    |    |-- shortestTimeToAceFromFirstTakedown: double (nullable = true)
#  |    |    |    |    |-- skillshotsDodged: long (nullable = true)
#  |    |    |    |    |-- skillshotsHit: long (nullable = true)
#  |    |    |    |    |-- snowballsHit: long (nullable = true)
#  |    |    |    |    |-- soloBaronKills: long (nullable = true)
#  |    |    |    |    |-- soloKills: long (nullable = true)
#  |    |    |    |    |-- soloTurretsLategame: long (nullable = true)
#  |    |    |    |    |-- stealthWardsPlaced: long (nullable = true)
#  |    |    |    |    |-- survivedSingleDigitHpCount: long (nullable = true)
#  |    |    |    |    |-- survivedThreeImmobilizesInFight: long (nullable = true)
#  |    |    |    |    |-- takedownOnFirstTurret: long (nullable = true)
#  |    |    |    |    |-- takedowns: long (nullable = true)
#  |    |    |    |    |-- takedownsAfterGainingLevelAdvantage: long (nullable = true)
#  |    |    |    |    |-- takedownsBeforeJungleMinionSpawn: long (nullable = true)
#  |    |    |    |    |-- takedownsFirstXMinutes: long (nullable = true)
#  |    |    |    |    |-- takedownsInAlcove: long (nullable = true)
#  |    |    |    |    |-- takedownsInEnemyFountain: long (nullable = true)
#  |    |    |    |    |-- teamBaronKills: long (nullable = true)
#  |    |    |    |    |-- teamDamagePercentage: double (nullable = true)
#  |    |    |    |    |-- teamElderDragonKills: long (nullable = true)
#  |    |    |    |    |-- teamRiftHeraldKills: long (nullable = true)
#  |    |    |    |    |-- teleportTakedowns: long (nullable = true)
#  |    |    |    |    |-- thirdInhibitorDestroyedTime: double (nullable = true)
#  |    |    |    |    |-- tookLargeDamageSurvived: long (nullable = true)
#  |    |    |    |    |-- turretPlatesTaken: long (nullable = true)
#  |    |    |    |    |-- turretTakedowns: long (nullable = true)
#  |    |    |    |    |-- turretsTakenWithRiftHerald: long (nullable = true)
#  |    |    |    |    |-- twentyMinionsIn3SecondsCount: long (nullable = true)
#  |    |    |    |    |-- twoWardsOneSweeperCount: long (nullable = true)
#  |    |    |    |    |-- unseenRecalls: long (nullable = true)
#  |    |    |    |    |-- visionScoreAdvantageLaneOpponent: double (nullable = true)
#  |    |    |    |    |-- visionScorePerMinute: double (nullable = true)
#  |    |    |    |    |-- wardTakedowns: long (nullable = true)
#  |    |    |    |    |-- wardTakedownsBefore20M: long (nullable = true)
#  |    |    |    |    |-- wardsGuarded: long (nullable = true)
#  |    |    |    |-- champExperience: long (nullable = true)
#  |    |    |    |-- champLevel: long (nullable = true)
#  |    |    |    |-- championId: long (nullable = true)
#  |    |    |    |-- championName: string (nullable = true)
#  |    |    |    |-- championTransform: long (nullable = true)
#  |    |    |    |-- commandPings: long (nullable = true)
#  |    |    |    |-- consumablesPurchased: long (nullable = true)
#  |    |    |    |-- damageDealtToBuildings: long (nullable = true)
#  |    |    |    |-- damageDealtToObjectives: long (nullable = true)
#  |    |    |    |-- damageDealtToTurrets: long (nullable = true)
#  |    |    |    |-- damageSelfMitigated: long (nullable = true)
#  |    |    |    |-- dangerPings: long (nullable = true)
#  |    |    |    |-- deaths: long (nullable = true)
#  |    |    |    |-- detectorWardsPlaced: long (nullable = true)
#  |    |    |    |-- doubleKills: long (nullable = true)
#  |    |    |    |-- dragonKills: long (nullable = true)
#  |    |    |    |-- eligibleForProgression: boolean (nullable = true)
#  |    |    |    |-- enemyMissingPings: long (nullable = true)
#  |    |    |    |-- enemyVisionPings: long (nullable = true)
#  |    |    |    |-- firstBloodAssist: boolean (nullable = true)
#  |    |    |    |-- firstBloodKill: boolean (nullable = true)
#  |    |    |    |-- firstTowerAssist: boolean (nullable = true)
#  |    |    |    |-- firstTowerKill: boolean (nullable = true)
#  |    |    |    |-- gameEndedInEarlySurrender: boolean (nullable = true)
#  |    |    |    |-- gameEndedInSurrender: boolean (nullable = true)
#  |    |    |    |-- getBackPings: long (nullable = true)
#  |    |    |    |-- goldEarned: long (nullable = true)
#  |    |    |    |-- goldSpent: long (nullable = true)
#  |    |    |    |-- holdPings: long (nullable = true)
#  |    |    |    |-- individualPosition: string (nullable = true)
#  |    |    |    |-- inhibitorKills: long (nullable = true)
#  |    |    |    |-- inhibitorTakedowns: long (nullable = true)
#  |    |    |    |-- inhibitorsLost: long (nullable = true)
#  |    |    |    |-- item0: long (nullable = true)
#  |    |    |    |-- item1: long (nullable = true)
#  |    |    |    |-- item2: long (nullable = true)
#  |    |    |    |-- item3: long (nullable = true)
#  |    |    |    |-- item4: long (nullable = true)
#  |    |    |    |-- item5: long (nullable = true)
#  |    |    |    |-- item6: long (nullable = true)
#  |    |    |    |-- itemsPurchased: long (nullable = true)
#  |    |    |    |-- killingSprees: long (nullable = true)
#  |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |-- lane: string (nullable = true)
#  |    |    |    |-- largestCriticalStrike: long (nullable = true)
#  |    |    |    |-- largestKillingSpree: long (nullable = true)
#  |    |    |    |-- largestMultiKill: long (nullable = true)
#  |    |    |    |-- longestTimeSpentLiving: long (nullable = true)
#  |    |    |    |-- magicDamageDealt: long (nullable = true)
#  |    |    |    |-- magicDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- magicDamageTaken: long (nullable = true)
#  |    |    |    |-- missions: struct (nullable = true)
#  |    |    |    |    |-- playerScore0: long (nullable = true)
#  |    |    |    |    |-- playerScore1: long (nullable = true)
#  |    |    |    |    |-- playerScore10: long (nullable = true)
#  |    |    |    |    |-- playerScore11: long (nullable = true)
#  |    |    |    |    |-- playerScore2: long (nullable = true)
#  |    |    |    |    |-- playerScore3: long (nullable = true)
#  |    |    |    |    |-- playerScore4: long (nullable = true)
#  |    |    |    |    |-- playerScore5: long (nullable = true)
#  |    |    |    |    |-- playerScore6: long (nullable = true)
#  |    |    |    |    |-- playerScore7: long (nullable = true)
#  |    |    |    |    |-- playerScore8: long (nullable = true)
#  |    |    |    |    |-- playerScore9: long (nullable = true)
#  |    |    |    |-- needVisionPings: long (nullable = true)
#  |    |    |    |-- neutralMinionsKilled: long (nullable = true)
#  |    |    |    |-- nexusKills: long (nullable = true)
#  |    |    |    |-- nexusLost: long (nullable = true)
#  |    |    |    |-- nexusTakedowns: long (nullable = true)
#  |    |    |    |-- objectivesStolen: long (nullable = true)
#  |    |    |    |-- objectivesStolenAssists: long (nullable = true)
#  |    |    |    |-- onMyWayPings: long (nullable = true)
#  |    |    |    |-- participantId: long (nullable = true)
#  |    |    |    |-- pentaKills: long (nullable = true)
#  |    |    |    |-- perks: struct (nullable = true)
#  |    |    |    |    |-- statPerks: struct (nullable = true)
#  |    |    |    |    |    |-- defense: long (nullable = true)
#  |    |    |    |    |    |-- flex: long (nullable = true)
#  |    |    |    |    |    |-- offense: long (nullable = true)
#  |    |    |    |    |-- styles: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- selections: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- perk: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- var1: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- var2: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- var3: long (nullable = true)
#  |    |    |    |    |    |    |-- style: long (nullable = true)
#  |    |    |    |-- physicalDamageDealt: long (nullable = true)
#  |    |    |    |-- physicalDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- physicalDamageTaken: long (nullable = true)
#  |    |    |    |-- placement: long (nullable = true)
#  |    |    |    |-- playerAugment1: long (nullable = true)
#  |    |    |    |-- playerAugment2: long (nullable = true)
#  |    |    |    |-- playerAugment3: long (nullable = true)
#  |    |    |    |-- playerAugment4: long (nullable = true)
#  |    |    |    |-- playerScore0: long (nullable = true)
#  |    |    |    |-- playerScore1: long (nullable = true)
#  |    |    |    |-- playerScore10: long (nullable = true)
#  |    |    |    |-- playerScore11: long (nullable = true)
#  |    |    |    |-- playerScore2: long (nullable = true)
#  |    |    |    |-- playerScore3: long (nullable = true)
#  |    |    |    |-- playerScore4: long (nullable = true)
#  |    |    |    |-- playerScore5: long (nullable = true)
#  |    |    |    |-- playerScore6: long (nullable = true)
#  |    |    |    |-- playerScore7: long (nullable = true)
#  |    |    |    |-- playerScore8: long (nullable = true)
#  |    |    |    |-- playerScore9: long (nullable = true)
#  |    |    |    |-- playerSubteamId: long (nullable = true)
#  |    |    |    |-- profileIcon: long (nullable = true)
#  |    |    |    |-- pushPings: long (nullable = true)
#  |    |    |    |-- puuid: string (nullable = true)
#  |    |    |    |-- quadraKills: long (nullable = true)
#  |    |    |    |-- riotIdGameName: string (nullable = true)
#  |    |    |    |-- riotIdName: string (nullable = true)
#  |    |    |    |-- riotIdTagline: string (nullable = true)
#  |    |    |    |-- role: string (nullable = true)
#  |    |    |    |-- sightWardsBoughtInGame: long (nullable = true)
#  |    |    |    |-- spell1Casts: long (nullable = true)
#  |    |    |    |-- spell2Casts: long (nullable = true)
#  |    |    |    |-- spell3Casts: long (nullable = true)
#  |    |    |    |-- spell4Casts: long (nullable = true)
#  |    |    |    |-- subteamPlacement: long (nullable = true)
#  |    |    |    |-- summoner1Casts: long (nullable = true)
#  |    |    |    |-- summoner1Id: long (nullable = true)
#  |    |    |    |-- summoner2Casts: long (nullable = true)
#  |    |    |    |-- summoner2Id: long (nullable = true)
#  |    |    |    |-- summonerId: string (nullable = true)
#  |    |    |    |-- summonerLevel: long (nullable = true)
#  |    |    |    |-- summonerName: string (nullable = true)
#  |    |    |    |-- teamEarlySurrendered: boolean (nullable = true)
#  |    |    |    |-- teamId: long (nullable = true)
#  |    |    |    |-- teamPosition: string (nullable = true)
#  |    |    |    |-- timeCCingOthers: long (nullable = true)
#  |    |    |    |-- timePlayed: long (nullable = true)
#  |    |    |    |-- totalAllyJungleMinionsKilled: long (nullable = true)
#  |    |    |    |-- totalDamageDealt: long (nullable = true)
#  |    |    |    |-- totalDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- totalDamageShieldedOnTeammates: long (nullable = true)
#  |    |    |    |-- totalDamageTaken: long (nullable = true)
#  |    |    |    |-- totalEnemyJungleMinionsKilled: long (nullable = true)
#  |    |    |    |-- totalHeal: long (nullable = true)
#  |    |    |    |-- totalHealsOnTeammates: long (nullable = true)
#  |    |    |    |-- totalMinionsKilled: long (nullable = true)
#  |    |    |    |-- totalTimeCCDealt: long (nullable = true)
#  |    |    |    |-- totalTimeSpentDead: long (nullable = true)
#  |    |    |    |-- totalUnitsHealed: long (nullable = true)
#  |    |    |    |-- tripleKills: long (nullable = true)
#  |    |    |    |-- trueDamageDealt: long (nullable = true)
#  |    |    |    |-- trueDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- trueDamageTaken: long (nullable = true)
#  |    |    |    |-- turretKills: long (nullable = true)
#  |    |    |    |-- turretTakedowns: long (nullable = true)
#  |    |    |    |-- turretsLost: long (nullable = true)
#  |    |    |    |-- unrealKills: long (nullable = true)
#  |    |    |    |-- visionClearedPings: long (nullable = true)
#  |    |    |    |-- visionScore: long (nullable = true)
#  |    |    |    |-- visionWardsBoughtInGame: long (nullable = true)
#  |    |    |    |-- wardsKilled: long (nullable = true)
#  |    |    |    |-- wardsPlaced: long (nullable = true)
#  |    |    |    |-- win: boolean (nullable = true)
#  |    |-- platformId: string (nullable = true)
#  |    |-- queueId: long (nullable = true)
#  |    |-- teams: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- bans: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- championId: long (nullable = true)
#  |    |    |    |    |    |-- pickTurn: long (nullable = true)
#  |    |    |    |-- objectives: struct (nullable = true)
#  |    |    |    |    |-- baron: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- champion: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- dragon: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- horde: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- inhibitor: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- riftHerald: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- tower: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |-- teamId: long (nullable = true)
#  |    |    |    |-- win: boolean (nullable = true)
#  |    |-- tournamentCode: string (nullable = true)
#  |-- metadata: struct (nullable = true)
#  |    |-- dataVersion: string (nullable = true)
#  |    |-- matchId: string (nullable = true)
#  |    |-- participants: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)

# %%
df.count()
# Out:
# 4065

# %%
df.show()
# Out:
# +---------------+--------------------+--------------------+
# |_corrupt_record|                info|            metadata|
# +---------------+--------------------+--------------------+
# |           NULL|{1702218495729, 1...|{2, VN2_263621944...|
# |           NULL|{1702214839655, 1...|{2, VN2_263529508...|
# |           NULL|{1702213456722, 1...|{2, VN2_263503073...|
# |           NULL|{1702212129650, 1...|{2, VN2_263457862...|
# |           NULL|{1702210448240, 1...|{2, VN2_263425557...|
# |           NULL|{1702208898115, 1...|{2, VN2_263406060...|
# |           NULL|{1702204199914, 1...|{2, VN2_263311776...|
# |           NULL|{1702141622861, 9...|{2, VN2_262473336...|
# |           NULL|{1702132388766, 1...|{2, VN2_262242252...|
# |           NULL|{1702130960818, 1...|{2, VN2_262199389...|
# |           NULL|{1702222055120, 2...|{2, VN2_263714400...|
# |           NULL|{1702219444484, 1...|{2, VN2_263646609...|
# |           NULL|{1702199204289, 9...|{2, VN2_263218782...|
# |           NULL|{1702198173404, 8...|{2, VN2_263197676...|
# |           NULL|{1702191634109, 1...|{2, VN2_263044875...|
# |           NULL|{1702188564973, 1...|{2, VN2_262988380...|
# |           NULL|{1702185444896, 1...|{2, VN2_262925166...|
# |           NULL|{1702184466858, 1...|{2, VN2_262906009...|
# |           NULL|{1702183314969, 9...|{2, VN2_262877464...|
# |           NULL|{1702182090806, 9...|{2, VN2_262859264...|
# +---------------+--------------------+--------------------+
# only showing top 20 rows

# %%
match_df = df.select(
    explode("info.participants").alias("participant"),
    "info.gameId",
    "info.gameMode",
    "info.gameType",
    "info.gameVersion",
    ).select(
    "gameId",
    "gameMode",
    "participant.riotIdGameName",
    "participant.championId",
    "participant.championName",
    "participant.lane",
    "participant.teamId",
    "participant.teamPosition",
    "participant.win",
).where("gameMode = 'CLASSIC'")

# %%
match_df.show(20)
# Out:
# +---------+--------+---------------+----------+------------+------+------+------------+-----+
# |   gameId|gameMode| riotIdGameName|championId|championName|  lane|teamId|teamPosition|  win|
# +---------+--------+---------------+----------+------------+------+------+------------+-----+
# |263311776| CLASSIC|          Kenbu|       114|       Fiora|   TOP|   100|         TOP| true|
# |263311776| CLASSIC|GOOD GAME GG XD|        64|      LeeSin|JUNGLE|   100|      JUNGLE| true|
# |263311776| CLASSIC|   tennaymanman|         8|    Vladimir|MIDDLE|   100|      MIDDLE| true|
# |263311776| CLASSIC|  not look back|       145|       Kaisa|BOTTOM|   100|      BOTTOM| true|
# |263311776| CLASSIC|  jonthelonewof|       497|       Rakan|BOTTOM|   100|     UTILITY| true|
# |263311776| CLASSIC|        Quankun|       777|        Yone|   TOP|   200|         TOP|false|
# |263311776| CLASSIC| Yêu Thiên Bình|        56|    Nocturne|JUNGLE|   200|      JUNGLE|false|
# |263311776| CLASSIC|     Kẽ Vẽ Mộng|         3|       Galio|MIDDLE|   200|      MIDDLE|false|
# |263311776| CLASSIC|          hvnow|       110|       Varus|BOTTOM|   200|      BOTTOM|false|
# |263311776| CLASSIC|  Đại Cao Thủ 1|       117|        Lulu|BOTTOM|   200|     UTILITY|false|
# |263714400| CLASSIC|       Slow1504|        86|       Garen|JUNGLE|   100|         TOP| true|
# |263714400| CLASSIC|   hoangkindred|       234|       Viego|JUNGLE|   100|      JUNGLE| true|
# |263714400| CLASSIC|   D2AegisGamer|        45|      Veigar|MIDDLE|   100|      MIDDLE| true|
# |263714400| CLASSIC|           A777|        51|     Caitlyn|MIDDLE|   100|      BOTTOM| true|
# |263714400| CLASSIC|       Gà mà Dơ|       161|      Velkoz|MIDDLE|   100|     UTILITY| true|
# |263714400| CLASSIC|         Origin|       223|   TahmKench|   TOP|   200|         TOP|false|
# |263714400| CLASSIC|  Hoàng đậm sâu|        59|    JarvanIV|JUNGLE|   200|      JUNGLE|false|
# |263714400| CLASSIC|         Divine|        99|         Lux|MIDDLE|   200|      MIDDLE|false|
# |263714400| CLASSIC|        Valésco|        81|      Ezreal|BOTTOM|   200|      BOTTOM|false|
# |263714400| CLASSIC|         n0tice|       555|        Pyke|BOTTOM|   200|     UTILITY|false|
# +---------+--------+---------------+----------+------------+------+------+------------+-----+
# only showing top 20 rows

# %%
match_df = match_df.withColumn("win", col("win").cast("integer"))

# %%
match_df.show(100)
# Out:
# +---------+--------+----------------+----------+------------+------+------+------------+---+
# |   gameId|gameMode|  riotIdGameName|championId|championName|  lane|teamId|teamPosition|win|
# +---------+--------+----------------+----------+------------+------+------+------------+---+
# |263311776| CLASSIC|           Kenbu|       114|       Fiora|   TOP|   100|         TOP|  1|
# |263311776| CLASSIC| GOOD GAME GG XD|        64|      LeeSin|JUNGLE|   100|      JUNGLE|  1|
# |263311776| CLASSIC|    tennaymanman|         8|    Vladimir|MIDDLE|   100|      MIDDLE|  1|
# |263311776| CLASSIC|   not look back|       145|       Kaisa|BOTTOM|   100|      BOTTOM|  1|
# |263311776| CLASSIC|   jonthelonewof|       497|       Rakan|BOTTOM|   100|     UTILITY|  1|
# |263311776| CLASSIC|         Quankun|       777|        Yone|   TOP|   200|         TOP|  0|
# |263311776| CLASSIC|  Yêu Thiên Bình|        56|    Nocturne|JUNGLE|   200|      JUNGLE|  0|
# |263311776| CLASSIC|      Kẽ Vẽ Mộng|         3|       Galio|MIDDLE|   200|      MIDDLE|  0|
# |263311776| CLASSIC|           hvnow|       110|       Varus|BOTTOM|   200|      BOTTOM|  0|
# |263311776| CLASSIC|   Đại Cao Thủ 1|       117|        Lulu|BOTTOM|   200|     UTILITY|  0|
# |263714400| CLASSIC|        Slow1504|        86|       Garen|JUNGLE|   100|         TOP|  1|
# |263714400| CLASSIC|    hoangkindred|       234|       Viego|JUNGLE|   100|      JUNGLE|  1|
# |263714400| CLASSIC|    D2AegisGamer|        45|      Veigar|MIDDLE|   100|      MIDDLE|  1|
# |263714400| CLASSIC|            A777|        51|     Caitlyn|MIDDLE|   100|      BOTTOM|  1|
# |263714400| CLASSIC|        Gà mà Dơ|       161|      Velkoz|MIDDLE|   100|     UTILITY|  1|
# |263714400| CLASSIC|          Origin|       223|   TahmKench|   TOP|   200|         TOP|  0|
# |263714400| CLASSIC|   Hoàng đậm sâu|        59|    JarvanIV|JUNGLE|   200|      JUNGLE|  0|
# |263714400| CLASSIC|          Divine|        99|         Lux|MIDDLE|   200|      MIDDLE|  0|
# |263714400| CLASSIC|         Valésco|        81|      Ezreal|BOTTOM|   200|      BOTTOM|  0|
# |263714400| CLASSIC|          n0tice|       555|        Pyke|BOTTOM|   200|     UTILITY|  0|
# |263646609| CLASSIC|      NTQ o XaKe|       115|       Ziggs|MIDDLE|   100|      MIDDLE|  0|
# |263646609| CLASSIC|        TrongHiu|        25|     Morgana|BOTTOM|   100|     UTILITY|  0|
# |263646609| CLASSIC|    hoangkindred|       234|       Viego|JUNGLE|   100|      JUNGLE|  0|
# |263646609| CLASSIC|NTT o Katy Perry|        21| MissFortune|BOTTOM|   100|      BOTTOM|  0|
# |263646609| CLASSIC|     SANGGIANGHO|        58|    Renekton|   TOP|   100|         TOP|  0|
# |263646609| CLASSIC|     ma tg ta na|       126|       Jayce|MIDDLE|   200|      MIDDLE|  1|
# |263646609| CLASSIC|         BiRiooo|       104|      Graves|JUNGLE|   200|      JUNGLE|  1|
# |263646609| CLASSIC|   Sore ga Spice|       429|     Kalista|BOTTOM|   200|      BOTTOM|  1|
# |263646609| CLASSIC|    Than Hạ Long|       412|      Thresh|BOTTOM|   200|     UTILITY|  1|
# |263646609| CLASSIC|     Bbi ThỏSkyy|        79|      Gragas|   TOP|   200|         TOP|  1|
# |263044875| CLASSIC|        Tuấn 5A1|        22|        Ashe|BOTTOM|   100|      BOTTOM|  1|
# |263044875| CLASSIC| bơi vô kiếm ăn |       101|      Xerath|MIDDLE|   100|      MIDDLE|  1|
# |263044875| CLASSIC|    Ấu Trùng Gầy|        25|     Morgana|BOTTOM|   100|     UTILITY|  1|
# |263044875| CLASSIC|         MyNhunn|       429|     Kalista|JUNGLE|   100|         TOP|  1|
# |263044875| CLASSIC|    hoangkindred|       234|       Viego|JUNGLE|   100|      JUNGLE|  1|
# |263044875| CLASSIC|      Cá Mắc Cạn|        34|      Anivia|BOTTOM|   200|     UTILITY|  0|
# |263044875| CLASSIC|      cá chà bặc|        63|       Brand|MIDDLE|   200|      MIDDLE|  0|
# |263044875| CLASSIC|         ShenNin|       245|        Ekko|JUNGLE|   200|      JUNGLE|  0|
# |263044875| CLASSIC| Cấy Chi Chi Rứa|        50|       Swain|BOTTOM|   200|      BOTTOM|  0|
# |263044875| CLASSIC|      Hoaa Tiêuu|        48|     Trundle|   TOP|   200|         TOP|  0|
# |262988380| CLASSIC|       chim trox|       266|      Aatrox|JUNGLE|   100|         TOP|  0|
# |262988380| CLASSIC|    hoangkindred|       234|       Viego|JUNGLE|   100|      JUNGLE|  0|
# |262988380| CLASSIC|      thanh thao|       103|        Ahri|MIDDLE|   100|      MIDDLE|  0|
# |262988380| CLASSIC|            hieu|       202|        Jhin|BOTTOM|   100|      BOTTOM|  0|
# |262988380| CLASSIC|     Mèo bé bỏng|        16|      Soraka|BOTTOM|   100|     UTILITY|  0|
# |262988380| CLASSIC| 300Gold biet di|       517|       Sylas|   TOP|   200|         TOP|  1|
# |262988380| CLASSIC|  Sóc lọ qua đêm|        35|       Shaco|JUNGLE|   200|      JUNGLE|  1|
# |262988380| CLASSIC|   Togipiforever|        81|      Ezreal|MIDDLE|   200|      MIDDLE|  1|
# |262988380| CLASSIC| Đố A Bắt Được E|        22|        Ashe|BOTTOM|   200|      BOTTOM|  1|
# |262988380| CLASSIC|        TheSephi|       910|        Hwei|BOTTOM|   200|     UTILITY|  1|
# |263690486| CLASSIC|           Fiora|       114|       Fiora|  NONE|   100|         TOP|  0|
# |263690486| CLASSIC|            MEER|        79|      Gragas|  NONE|   100|      JUNGLE|  0|
# |263690486| CLASSIC|        LandLove|       238|         Zed|  NONE|   100|      MIDDLE|  0|
# |263690486| CLASSIC|      1dammayden|       145|       Kaisa|  NONE|   100|      BOTTOM|  0|
# |263690486| CLASSIC|Cardi B Việt Nam|       267|        Nami|  NONE|   100|     UTILITY|  0|
# |263690486| CLASSIC|  Vô Thị Hồng Ly|        58|    Renekton|  NONE|   200|         TOP|  1|
# |263690486| CLASSIC|         OG Myth|       141|        Kayn|  NONE|   200|      JUNGLE|  1|
# |263690486| CLASSIC|   toi pun vi ai|       163|     Taliyah|  NONE|   200|      MIDDLE|  1|
# |263690486| CLASSIC|     UEH Gia Qui|       222|        Jinx|  NONE|   200|      BOTTOM|  1|
# |263690486| CLASSIC|            Soju|        16|      Soraka|  NONE|   200|     UTILITY|  1|
# |263632619| CLASSIC|    Qnhi x Tbinh|        84|       Akali|  NONE|   100|         TOP|  1|
# |263632619| CLASSIC|       WoQingXin|        33|      Rammus|  NONE|   100|      JUNGLE|  1|
# |263632619| CLASSIC|     UEH Gia Qui|       777|        Yone|  NONE|   100|      MIDDLE|  1|
# |263632619| CLASSIC|  Huang Ru Qiong|       236|      Lucian|  NONE|   100|      BOTTOM|  1|
# |263632619| CLASSIC|       nựng nựng|       902|       Milio|  NONE|   100|     UTILITY|  1|
# |263632619| CLASSIC|  Con Hổ Đần uwu|        92|       Riven|  NONE|   200|         TOP|  0|
# |263632619| CLASSIC|          Dreach|       104|      Graves|  NONE|   200|      JUNGLE|  0|
# |263632619| CLASSIC|             Zoe|       142|         Zoe|  NONE|   200|      MIDDLE|  0|
# |263632619| CLASSIC|   하오 잘생겼다|       895|       Nilah|  NONE|   200|      BOTTOM|  0|
# |263632619| CLASSIC|           qdinh|       350|       Yuumi|  NONE|   200|     UTILITY|  0|
# |263572878| CLASSIC|   tandatnguyen1|        54|    Malphite|   TOP|   100|         TOP|  1|
# |263572878| CLASSIC|      Quang Phạm|        64|      LeeSin|JUNGLE|   100|      JUNGLE|  1|
# |263572878| CLASSIC|  Capta1n Em Lạc|       157|       Yasuo|MIDDLE|   100|      MIDDLE|  1|
# |263572878| CLASSIC|     UEH Gia Qui|        51|     Caitlyn|BOTTOM|   100|      BOTTOM|  1|
# |263572878| CLASSIC|ıIılılIlılılıIıı|        99|         Lux|BOTTOM|   100|     UTILITY|  1|
# |263572878| CLASSIC|   Hakuna Matata|        84|       Akali|   TOP|   200|         TOP|  0|
# |263572878| CLASSIC|       Celebrity|        59|    JarvanIV|JUNGLE|   200|      JUNGLE|  0|
# |263572878| CLASSIC|      anagapesis|       126|       Jayce|MIDDLE|   200|      MIDDLE|  0|
# |263572878| CLASSIC|    meowmeow1810|       429|     Kalista|JUNGLE|   200|      BOTTOM|  0|
# |263572878| CLASSIC|  em Boo lon mup|       111|    Nautilus|BOTTOM|   200|     UTILITY|  0|
# |260001330| CLASSIC|  Tôi sẽ trở lại|       777|        Yone|  NONE|   100|         TOP|  0|
# |260001330| CLASSIC| mot con ca cute|        79|      Gragas|  NONE|   100|      JUNGLE|  0|
# |260001330| CLASSIC|           Fátk3|        39|      Irelia|  NONE|   100|      MIDDLE|  0|
# |260001330| CLASSIC|HST Hưng2 MậpMạp|       110|       Varus|  NONE|   100|      BOTTOM|  0|
# |260001330| CLASSIC| EatYourHeartOut|        37|        Sona|  NONE|   100|     UTILITY|  0|
# |260001330| CLASSIC|       T1 문현준|        84|       Akali|  NONE|   200|         TOP|  1|
# |260001330| CLASSIC| du hoc dai loan|        59|    JarvanIV|  NONE|   200|      JUNGLE|  1|
# |260001330| CLASSIC|            nyan|       126|       Jayce|  NONE|   200|      MIDDLE|  1|
# |260001330| CLASSIC|      迟来的情话|       145|       Kaisa|  NONE|   200|      BOTTOM|  1|
# |260001330| CLASSIC|      hodaihuynh|        53|  Blitzcrank|  NONE|   200|     UTILITY|  1|
# |259965821| CLASSIC|          200795|        58|    Renekton|   TOP|   100|         TOP|  0|
# |259965821| CLASSIC| mot con ca cute|        59|    JarvanIV|JUNGLE|   100|      JUNGLE|  0|
# |259965821| CLASSIC|          Kikosy|        22|        Ashe|BOTTOM|   100|     UTILITY|  0|
# |259965821| CLASSIC|      miss fishh|       110|       Varus|BOTTOM|   100|      BOTTOM|  0|
# |259965821| CLASSIC|          pkvip1|        61|     Orianna|MIDDLE|   100|      MIDDLE|  0|
# |259965821| CLASSIC|            nyan|        24|         Jax|   TOP|   200|         TOP|  1|
# |259965821| CLASSIC|       Apoii 420|        64|      LeeSin|JUNGLE|   200|      JUNGLE|  1|
# |259965821| CLASSIC|         Phuc To|       127|   Lissandra|MIDDLE|   200|      MIDDLE|  1|
# |259965821| CLASSIC|          Irelia|       222|        Jinx|BOTTOM|   200|      BOTTOM|  1|
# |259965821| CLASSIC|      trangtrang|       555|        Pyke|BOTTOM|   200|     UTILITY|  1|
# +---------+--------+----------------+----------+------------+------+------+------------+---+
# only showing top 100 rows

# %%
from pyspark.sql.functions import col, count, sum
win_rate_df = match_df.groupBy("championName") \
    .agg(
        sum("win").alias("totalWins"), 
        count("win").alias("totalGames")
    ) \
    .withColumn("winRate", col("totalWins") / col("totalGames")) \
    .orderBy("championName")

# %%
win_rate_df.show(200)
# Out:
# +------------+---------+----------+-------------------+
# |championName|totalWins|totalGames|            winRate|
# +------------+---------+----------+-------------------+
# |      Aatrox|      239|       493| 0.4847870182555781|
# |        Ahri|       50|       145| 0.3448275862068966|
# |       Akali|      202|       397| 0.5088161209068011|
# |      Akshan|       34|        51| 0.6666666666666666|
# |     Alistar|       79|       173|0.45664739884393063|
# |       Amumu|        8|        12| 0.6666666666666666|
# |      Anivia|       27|        44| 0.6136363636363636|
# |       Annie|       14|        35|                0.4|
# |    Aphelios|       94|       189| 0.4973544973544973|
# |        Ashe|      130|       273|0.47619047619047616|
# | AurelionSol|       19|        52|0.36538461538461536|
# |        Azir|       38|        91| 0.4175824175824176|
# |        Bard|       37|        93| 0.3978494623655914|
# |     Belveth|       76|       113|  0.672566371681416|
# |  Blitzcrank|       83|       169| 0.4911242603550296|
# |       Brand|       40|        93|0.43010752688172044|
# |       Braum|       31|        62|                0.5|
# |       Briar|       21|        44| 0.4772727272727273|
# |     Caitlyn|      134|       235| 0.5702127659574469|
# |     Camille|       56|       113|0.49557522123893805|
# |  Cassiopeia|       17|        37| 0.4594594594594595|
# |     Chogath|        4|        14| 0.2857142857142857|
# |       Corki|       11|        16|             0.6875|
# |      Darius|       53|       108|0.49074074074074076|
# |       Diana|       53|       101| 0.5247524752475248|
# |     DrMundo|        6|        12|                0.5|
# |      Draven|       30|        72| 0.4166666666666667|
# |        Ekko|       53|       125|              0.424|
# |       Elise|       12|        27| 0.4444444444444444|
# |     Evelynn|       37|        85|0.43529411764705883|
# |      Ezreal|      263|       585| 0.4495726495726496|
# |FiddleSticks|       27|        41| 0.6585365853658537|
# |       Fiora|      109|       210| 0.5190476190476191|
# |        Fizz|       26|        50|               0.52|
# |       Galio|       29|        55| 0.5272727272727272|
# |   Gangplank|       53|       107| 0.4953271028037383|
# |       Garen|       23|        43| 0.5348837209302325|
# |        Gnar|       46|        88| 0.5227272727272727|
# |      Gragas|       77|       171| 0.4502923976608187|
# |      Graves|      314|       614|  0.511400651465798|
# |        Gwen|       67|       109| 0.6146788990825688|
# |     Hecarim|       82|       175| 0.4685714285714286|
# |Heimerdinger|        9|        18|                0.5|
# |        Hwei|      101|       339|0.29793510324483774|
# |      Illaoi|       22|        38| 0.5789473684210527|
# |      Irelia|      116|       231| 0.5021645021645021|
# |       Ivern|        8|        13| 0.6153846153846154|
# |       Janna|       60|       131| 0.4580152671755725|
# |    JarvanIV|      107|       273|0.39194139194139194|
# |         Jax|      238|       446| 0.5336322869955157|
# |       Jayce|      280|       547| 0.5118829981718465|
# |        Jhin|      156|       297| 0.5252525252525253|
# |        Jinx|      145|       271| 0.5350553505535055|
# |      KSante|       99|       202| 0.4900990099009901|
# |       Kaisa|      506|       968| 0.5227272727272727|
# |     Kalista|      133|       294| 0.4523809523809524|
# |       Karma|       94|       210|0.44761904761904764|
# |     Karthus|       62|       110| 0.5636363636363636|
# |    Kassadin|       31|        56| 0.5535714285714286|
# |    Katarina|       48|        93| 0.5161290322580645|
# |       Kayle|       21|        38| 0.5526315789473685|
# |        Kayn|       90|       192|            0.46875|
# |      Kennen|       27|        71|0.38028169014084506|
# |      Khazix|      171|       368|0.46467391304347827|
# |     Kindred|      106|       161| 0.6583850931677019|
# |        Kled|       20|        38| 0.5263157894736842|
# |      KogMaw|       10|        17| 0.5882352941176471|
# |     Leblanc|       95|       168| 0.5654761904761905|
# |      LeeSin|      365|       667| 0.5472263868065967|
# |       Leona|       23|        47|0.48936170212765956|
# |      Lillia|       11|        29| 0.3793103448275862|
# |   Lissandra|       24|        70|0.34285714285714286|
# |      Lucian|      126|       246| 0.5121951219512195|
# |        Lulu|      102|       194| 0.5257731958762887|
# |         Lux|      104|       185| 0.5621621621621622|
# |    Malphite|       66|       127| 0.5196850393700787|
# |    Malzahar|       16|        38|0.42105263157894735|
# |      Maokai|       27|        55| 0.4909090909090909|
# |    MasterYi|       77|       148| 0.5202702702702703|
# |       Milio|       66|       107|  0.616822429906542|
# | MissFortune|       19|        43| 0.4418604651162791|
# |  MonkeyKing|        7|        36|0.19444444444444445|
# | Mordekaiser|       17|        34|                0.5|
# |     Morgana|       27|        66| 0.4090909090909091|
# |     Naafiri|        7|        11| 0.6363636363636364|
# |        Nami|       60|       156|0.38461538461538464|
# |       Nasus|       15|        32|            0.46875|
# |    Nautilus|      138|       259| 0.5328185328185329|
# |       Neeko|       57|       124| 0.4596774193548387|
# |     Nidalee|      157|       306| 0.5130718954248366|
# |       Nilah|       62|       117| 0.5299145299145299|
# |    Nocturne|       46|       102|0.45098039215686275|
# |        Nunu|       14|        26| 0.5384615384615384|
# |        Olaf|       64|       105| 0.6095238095238096|
# |     Orianna|      159|       303| 0.5247524752475248|
# |        Ornn|       38|        78|0.48717948717948717|
# |    Pantheon|       31|        73| 0.4246575342465753|
# |       Poppy|       40|        74| 0.5405405405405406|
# |        Pyke|      124|       263| 0.4714828897338403|
# |      Qiyana|       76|       127| 0.5984251968503937|
# |       Quinn|        6|        15|                0.4|
# |       Rakan|      188|       328|  0.573170731707317|
# |      Rammus|       15|        33|0.45454545454545453|
# |      RekSai|        6|        18| 0.3333333333333333|
# |        Rell|       96|       226| 0.4247787610619469|
# |      Renata|       64|       117| 0.5470085470085471|
# |    Renekton|      159|       290| 0.5482758620689655|
# |      Rengar|       57|        89| 0.6404494382022472|
# |       Riven|       52|       105|0.49523809523809526|
# |      Rumble|       50|        90| 0.5555555555555556|
# |        Ryze|       23|        51|0.45098039215686275|
# |      Samira|       61|       137|0.44525547445255476|
# |     Sejuani|        9|        36|               0.25|
# |       Senna|      103|       203| 0.5073891625615764|
# |   Seraphine|       26|        44| 0.5909090909090909|
# |        Sett|       25|        59|  0.423728813559322|
# |       Shaco|       24|        46| 0.5217391304347826|
# |        Shen|        8|        16|                0.5|
# |     Shyvana|       10|        19| 0.5263157894736842|
# |      Singed|       30|        61| 0.4918032786885246|
# |        Sion|       21|        52|0.40384615384615385|
# |       Sivir|       50|        88| 0.5681818181818182|
# |     Skarner|        1|         1|                1.0|
# |        Sona|       21|        34| 0.6176470588235294|
# |      Soraka|       92|       154| 0.5974025974025974|
# |       Swain|       38|        65| 0.5846153846153846|
# |       Sylas|      316|       609| 0.5188834154351396|
# |      Syndra|      112|       222| 0.5045045045045045|
# |   TahmKench|       23|        36| 0.6388888888888888|
# |     Taliyah|      155|       296| 0.5236486486486487|
# |       Talon|       23|        41| 0.5609756097560976|
# |       Taric|        6|        18| 0.3333333333333333|
# |       Teemo|        8|        29|0.27586206896551724|
# |      Thresh|      146|       296|0.49324324324324326|
# |    Tristana|       77|       148| 0.5202702702702703|
# |     Trundle|       24|        67| 0.3582089552238806|
# |  Tryndamere|       31|        67| 0.4626865671641791|
# | TwistedFate|       69|       120|              0.575|
# |      Twitch|       50|        95| 0.5263157894736842|
# |        Udyr|       58|        97| 0.5979381443298969|
# |       Urgot|       13|        28| 0.4642857142857143|
# |       Varus|      162|       378|0.42857142857142855|
# |       Vayne|       38|        80|              0.475|
# |      Veigar|       14|        34| 0.4117647058823529|
# |      Velkoz|       22|        37| 0.5945945945945946|
# |         Vex|       29|        45| 0.6444444444444445|
# |          Vi|       37|        82|0.45121951219512196|
# |       Viego|      125|       260| 0.4807692307692308|
# |      Viktor|       62|       119| 0.5210084033613446|
# |    Vladimir|       27|        52| 0.5192307692307693|
# |    Volibear|       14|        29| 0.4827586206896552|
# |     Warwick|        3|        13|0.23076923076923078|
# |       Xayah|      185|       345| 0.5362318840579711|
# |      Xerath|       84|       169| 0.4970414201183432|
# |     XinZhao|       14|        30| 0.4666666666666667|
# |       Yasuo|      114|       230| 0.4956521739130435|
# |        Yone|      281|       593|0.47386172006745364|
# |      Yorick|       13|        28| 0.4642857142857143|
# |       Yuumi|      119|       228| 0.5219298245614035|
# |         Zac|       35|        80|             0.4375|
# |         Zed|       42|        89|0.47191011235955055|
# |        Zeri|       78|       152| 0.5131578947368421|
# |       Ziggs|       29|        61|0.47540983606557374|
# |      Zilean|       23|        39| 0.5897435897435898|
# |         Zoe|      103|       184| 0.5597826086956522|
# |        Zyra|       27|        37| 0.7297297297297297|
# +------------+---------+----------+-------------------+

# %%
match_df.select("*").where("teamPosition is NULL").show()
# Out:
# +------+--------+--------------+----------+------------+----+------+------------+---+
# |gameId|gameMode|riotIdGameName|championId|championName|lane|teamId|teamPosition|win|
# +------+--------+--------------+----------+------------+----+------+------------+---+
# +------+--------+--------------+----------+------------+----+------+------------+---+

# %%
match_df_unique = match_df.dropDuplicates()

# %%
match_df_unique.count()
# Out:
# 17950

# %%
match_df.count()
# Out:
# 23500

# %%
win_rate_unique_df = match_df_unique.groupBy("championName") \
    .agg(
        sum("win").alias("totalWins"), 
        count("win").alias("totalGames")
    ) \
    .withColumn("winRate", col("totalWins") / col("totalGames")) \
    .orderBy("championName")

# %%
win_rate_unique_df.show()
# Out:
# +------------+---------+----------+-------------------+
# |championName|totalWins|totalGames|            winRate|
# +------------+---------+----------+-------------------+
# |      Aatrox|      194|       403| 0.4813895781637717|
# |        Ahri|       44|       120|0.36666666666666664|
# |       Akali|      151|       303|0.49834983498349833|
# |      Akshan|       23|        37| 0.6216216216216216|
# |     Alistar|       54|       123|0.43902439024390244|
# |       Amumu|        7|        11| 0.6363636363636364|
# |      Anivia|       16|        32|                0.5|
# |       Annie|       10|        24| 0.4166666666666667|
# |    Aphelios|       67|       136|0.49264705882352944|
# |        Ashe|      108|       214| 0.5046728971962616|
# | AurelionSol|       15|        37|0.40540540540540543|
# |        Azir|       31|        71|0.43661971830985913|
# |        Bard|       24|        61|0.39344262295081966|
# |     Belveth|       49|        79|  0.620253164556962|
# |  Blitzcrank|       67|       135| 0.4962962962962963|
# |       Brand|       29|        70| 0.4142857142857143|
# |       Braum|       23|        43| 0.5348837209302325|
# |       Briar|       20|        43|0.46511627906976744|
# |     Caitlyn|      101|       180| 0.5611111111111111|
# |     Camille|       46|        91| 0.5054945054945055|
# +------------+---------+----------+-------------------+
# only showing top 20 rows

# %%
win_rate_df.show()
# Out:
# +------------+---------+----------+-------------------+
# |championName|totalWins|totalGames|            winRate|
# +------------+---------+----------+-------------------+
# |      Aatrox|      239|       493| 0.4847870182555781|
# |        Ahri|       50|       145| 0.3448275862068966|
# |       Akali|      202|       397| 0.5088161209068011|
# |      Akshan|       34|        51| 0.6666666666666666|
# |     Alistar|       79|       173|0.45664739884393063|
# |       Amumu|        8|        12| 0.6666666666666666|
# |      Anivia|       27|        44| 0.6136363636363636|
# |       Annie|       14|        35|                0.4|
# |    Aphelios|       94|       189| 0.4973544973544973|
# |        Ashe|      130|       273|0.47619047619047616|
# | AurelionSol|       19|        52|0.36538461538461536|
# |        Azir|       38|        91| 0.4175824175824176|
# |        Bard|       37|        93| 0.3978494623655914|
# |     Belveth|       76|       113|  0.672566371681416|
# |  Blitzcrank|       83|       169| 0.4911242603550296|
# |       Brand|       40|        93|0.43010752688172044|
# |       Braum|       31|        62|                0.5|
# |       Briar|       21|        44| 0.4772727272727273|
# |     Caitlyn|      134|       235| 0.5702127659574469|
# |     Camille|       56|       113|0.49557522123893805|
# +------------+---------+----------+-------------------+
# only showing top 20 rows

# %% [markdown]
# # GET THE WIN RATE OF MATCHUP

# %%
match_df_unique.createOrReplaceTempView("match")

# %%
join_query = """
SELECT m1.gameId, m1.championName as champion1, m2.championName as champion2,m1.teamPosition, m2.teamPosition,m1.teamId as team1, m2.teamId as team2, m1.win
FROM match m1, match m2
WHERE m1.gameId = m2.gameId 
    AND m1.teamPosition = m2.teamPosition
    AND m1.teamId != m2.teamId
"""

# %%
matchup_each_game_df = spark.sql(join_query)

# %%
matchup_each_game_df.show()
# Out:
# +---------+-----------+----------+------------+------------+-----+-----+---+
# |   gameId|  champion1| champion2|teamPosition|teamPosition|team1|team2|win|
# +---------+-----------+----------+------------+------------+-----+-----+---+
# |260001330|       Sona|Blitzcrank|     UTILITY|     UTILITY|  100|  200|  0|
# |261519000|    Alistar|      Pyke|     UTILITY|     UTILITY|  100|  200|  0|
# |263905840|       Hwei|     Brand|     UTILITY|     UTILITY|  100|  200|  0|
# |263161124|     Xerath|      Zyra|     UTILITY|     UTILITY|  100|  200|  0|
# |260785481|     Graves|   Kindred|      JUNGLE|      JUNGLE|  100|  200|  1|
# |262101218|MissFortune|      Lulu|     UTILITY|     UTILITY|  200|  100|  0|
# |260339888|       Jinx|     Kaisa|      BOTTOM|      BOTTOM|  200|  100|  0|
# |261754134|       Nami|Blitzcrank|     UTILITY|     UTILITY|  100|  200|  1|
# |261405569| Blitzcrank|    Twitch|     UTILITY|     UTILITY|  200|  100|  0|
# |248821392|        Zed|  Vladimir|      MIDDLE|      MIDDLE|  100|  200|  1|
# |263370191|       Rell|   Alistar|     UTILITY|     UTILITY|  100|  200|  0|
# |263287051|        Jax|     Fiora|         TOP|         TOP|  100|  200|  0|
# |259965821|       Ashe|      Pyke|     UTILITY|     UTILITY|  100|  200|  0|
# |261957704|     Syndra|      Ahri|      MIDDLE|      MIDDLE|  200|  100|  1|
# |259020904|     Graves|    RekSai|      JUNGLE|      JUNGLE|  100|  200|  1|
# |255800544|     Khazix|    Graves|      JUNGLE|      JUNGLE|  100|  200|  0|
# |263232117|      Xayah|     Kaisa|      BOTTOM|      BOTTOM|  100|  200|  1|
# |263820079|      Annie|      Bard|     UTILITY|     UTILITY|  100|  200|  0|
# |256015522|      Ziggs|   Caitlyn|      BOTTOM|      BOTTOM|  200|  100|  0|
# |262663651|      Sylas|      Yone|      MIDDLE|      MIDDLE|  200|  100|  0|
# +---------+-----------+----------+------------+------------+-----+-----+---+
# only showing top 20 rows

# %%
matchup_df = matchup_each_game_df.groupBy('champion1', 'champion2').agg(
    sum('win').alias('total_wins'),
    count('gameId').alias('total_games')
).withColumn('champion1_win_rate', col('total_wins') / col('total_games')).orderBy('champion1', 'champion2')

# %%
matchup_df.show()
# Out:
# +---------+------------+----------+-----------+-------------------+
# |champion1|   champion2|total_wins|total_games| champion1_win_rate|
# +---------+------------+----------+-----------+-------------------+
# |   Aatrox|      Aatrox|         1|          2|                0.5|
# |   Aatrox|       Akali|         8|         16|                0.5|
# |   Aatrox|     Camille|         4|          9| 0.4444444444444444|
# |   Aatrox|  Cassiopeia|         1|          1|                1.0|
# |   Aatrox|      Darius|         5|         12| 0.4166666666666667|
# |   Aatrox|     DrMundo|         1|          1|                1.0|
# |   Aatrox|      Draven|         1|          2|                0.5|
# |   Aatrox|       Fiora|         6|         17|0.35294117647058826|
# |   Aatrox|        Fizz|         0|          1|                0.0|
# |   Aatrox|   Gangplank|         4|          7| 0.5714285714285714|
# |   Aatrox|       Garen|         2|          3| 0.6666666666666666|
# |   Aatrox|        Gnar|         4|          6| 0.6666666666666666|
# |   Aatrox|      Graves|         2|          3| 0.6666666666666666|
# |   Aatrox|        Gwen|         5|         11|0.45454545454545453|
# |   Aatrox|Heimerdinger|         0|          1|                0.0|
# |   Aatrox|        Hwei|         2|          2|                1.0|
# |   Aatrox|      Illaoi|         1|          2|                0.5|
# |   Aatrox|      Irelia|         0|         11|                0.0|
# |   Aatrox|         Jax|        19|         34| 0.5588235294117647|
# |   Aatrox|       Jayce|        19|         39|0.48717948717948717|
# +---------+------------+----------+-----------+-------------------+
# only showing top 20 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql import functions as F
matchups_over_30_games = matchup_df.filter(F.col('total_games') > 30)
windowSpec = Window.partitionBy('champion1').orderBy('champion1_win_rate')
ranked_matchups = matchups_over_30_games.withColumn("rank", F.row_number().over(windowSpec))
worst_matchups = ranked_matchups.filter(F.col("rank") <= 5)
worst_matchups.show()
# Out:
# +---------+---------+----------+-----------+-------------------+----+
# |champion1|champion2|total_wins|total_games| champion1_win_rate|rank|
# +---------+---------+----------+-----------+-------------------+----+
# |   Aatrox|     Yone|        17|         39| 0.4358974358974359|   1|
# |   Aatrox|    Jayce|        19|         39|0.48717948717948717|   2|
# |   Aatrox|      Jax|        19|         34| 0.5588235294117647|   3|
# | Aphelios|    Kaisa|        13|         31|0.41935483870967744|   1|
# |  Caitlyn|   Ezreal|        15|         32|            0.46875|   1|
# |   Ezreal|    Kaisa|        61|        121| 0.5041322314049587|   1|
# |   Ezreal|  Caitlyn|        17|         32|            0.53125|   2|
# |   Ezreal|    Varus|        18|         31| 0.5806451612903226|   3|
# |   Graves|   Khazix|        19|         38|                0.5|   1|
# |   Graves|   LeeSin|        53|         97| 0.5463917525773195|   2|
# | JarvanIV|   LeeSin|        16|         41| 0.3902439024390244|   1|
# |      Jax|   Aatrox|        15|         34| 0.4411764705882353|   1|
# |      Jax|     Yone|        22|         35| 0.6285714285714286|   2|
# |    Jayce|   Aatrox|        20|         39| 0.5128205128205128|   1|
# |    Jayce|     Yone|        17|         31| 0.5483870967741935|   2|
# |     Jhin|    Kaisa|        24|         39| 0.6153846153846154|   1|
# |     Jinx|    Kaisa|        29|         53| 0.5471698113207547|   1|
# |    Kaisa|     Jhin|        15|         39|0.38461538461538464|   1|
# |    Kaisa|    Nilah|        14|         32|             0.4375|   2|
# |    Kaisa|    Xayah|        42|         95| 0.4421052631578947|   3|
# +---------+---------+----------+-----------+-------------------+----+
# only showing top 20 rows
